# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv("C:\\Users\\mahes\\Downloads\\gapMinder-FiveYearData.csv")

# %%
df = pd.DataFrame(dt)

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                        country  year           pop continent   lifeExp  \
# 0                  Afghanistan  1952  8.425333e+06      Asia  28.80100
# 1                  Afghanistan  1957  9.240934e+06      Asia  30.33200
# 2                  Afghanistan  1962  1.026708e+07      Asia  31.99700
# 3                  Afghanistan  1967  1.153797e+07      Asia  34.02000
# 4                  Afghanistan  1972  1.307946e+07      Asia  36.08800
# 5                  Afghanistan  1977  1.488037e+07      Asia  38.43800
# 6                  Afghanistan  1982  1.288182e+07      Asia  39.85400
# 7                  Afghanistan  1987  1.386796e+07      Asia  40.82200
# 8                  Afghanistan  1992  1.631792e+07      Asia  41.67400
# 9                  Afghanistan  1997  2.222742e+07      Asia  41.76300
# 10                 Afghanistan  2002  2.526840e+07      Asia  42.12900
# 11                 Afghanistan  2007  3.188992e+07      Asia  43.82800
# ...

# %%
print(df.head())
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
print(df.shape)
# Out:
# (1704, 6)

# %%
print(df.columns)
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
print(df.dtypes)
# Out:
# country       object
# year           int64
# pop          float64
# continent     object
# lifeExp      float64
# gdpPercap    float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB
# None

# %%
country_df = df['country']

# %%
print(country_df.head())
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
print(country_df.tail())
# Out:
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object

# %%
subset = df[['country','continent','year']]

# %%
print(subset.head())
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
df.loc[0]
# Out:
# country      Afghanistan
# year                1952
# pop            8425333.0
# continent           Asia
# lifeExp           28.801
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[99]
# Out:
# country      Bangladesh
# year               1967
# pop          62821884.0
# continent          Asia
# lifeExp          43.453
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
print(df.tail(n=1))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
print(df.loc[[0,99,999]])
# Out:
#          country  year         pop continent  lifeExp    gdpPercap
# 0    Afghanistan  1952   8425333.0      Asia   28.801   779.445314
# 99    Bangladesh  1967  62821884.0      Asia   43.453   721.186086
# 999     Mongolia  1967   1149500.0      Asia   51.253  1226.041130

# %%
print(df.iloc[1])
# Out:
# country      Afghanistan
# year                1957
# pop            9240934.0
# continent           Asia
# lifeExp           30.332
# gdpPercap      820.85303
# Name: 1, dtype: object

# %%
print(df.iloc[99])
# Out:
# country      Bangladesh
# year               1967
# pop          62821884.0
# continent          Asia
# lifeExp          43.453
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
print(df.iloc[-1])
# Out:
# country        Zimbabwe
# year               2007
# pop          12311143.0
# continent        Africa
# lifeExp          43.487
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
subset = df.loc[:,['year' , 'pop']]
print(subset.head())
# Out:
#    year         pop
# 0  1952   8425333.0
# 1  1957   9240934.0
# 2  1962  10267083.0
# 3  1967  11537966.0
# 4  1972  13079460.0

# %%
subset = df.iloc[:, [2, 4, -1]]
print(subset.head())
# Out:
#           pop  lifeExp   gdpPercap
# 0   8425333.0   28.801  779.445314
# 1   9240934.0   30.332  820.853030
# 2  10267083.0   31.997  853.100710
# 3  11537966.0   34.020  836.197138
# 4  13079460.0   36.088  739.981106

# %%
small_range = list(range(5))
print(small_range)
# Out:
# [0, 1, 2, 3, 4]

# %%
subset = df.iloc[:,small_range]

# %%
print(subset.head())
# Out:
#        country  year         pop continent  lifeExp
# 0  Afghanistan  1952   8425333.0      Asia   28.801
# 1  Afghanistan  1957   9240934.0      Asia   30.332
# 2  Afghanistan  1962  10267083.0      Asia   31.997
# 3  Afghanistan  1967  11537966.0      Asia   34.020
# 4  Afghanistan  1972  13079460.0      Asia   36.088

# %%
print(df.loc[42,'country'])
# Out:
# Angola

# %%
print(df.iloc[[0,99,99], [0,3,5]])
# Out:
#         country continent   gdpPercap
# 0   Afghanistan      Asia  779.445314
# 99   Bangladesh      Asia  721.186086
# 99   Bangladesh      Asia  721.186086

# %%
print(df.iloc[42,0])
# Out:
# Angola

# %%
print(df.loc[[0,99,99], ['country','lifeExp' , 'gdpPercap']])
# Out:
#         country  lifeExp   gdpPercap
# 0   Afghanistan   28.801  779.445314
# 99   Bangladesh   43.453  721.186086
# 99   Bangladesh   43.453  721.186086

# %%
print(df.loc[10:13, ['country','lifeExp' , 'gdpPercap']])
# Out:
#         country  lifeExp    gdpPercap
# 10  Afghanistan   42.129   726.734055
# 11  Afghanistan   43.828   974.580338
# 12      Albania   55.230  1601.056136
# 13      Albania   59.280  1942.284244

# %%
print(df.head(n=10))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %%
print(df.groupby('year')['lifeExp'].mean())
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
multi_group_var = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()

# %%
multi_group_var
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
flat = multi_group_var.reset_index()

# %%
flat
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %%
print(df.groupby('continent')['country'].nunique())
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()

# %%
global_yearly_life_expectancy
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
global_yearly_life_expectancy.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
 txt = {'assessment_result': [{'description': 'Identifies problems the patient wishes to address', 'item_id': 1, 'name': 'item_problem_identification', 'rating': 0, 'skill_sets': [{'conv_part': 'Initiating the session', 'description': 'Greets patients', 'name': '', 'skill_id': 1.1, 'status': False}, {'conv_part': 'Initiating the session', 'description': 'Introduces oneself, one’s role and the nature of the interview', 'keywords': ["i'm gonna be your nurse today"], 'name': '', 'relevant_timeframes': [{'end_time': 25.56, 'start_time': 24.41, 'text': "i'm gonna be your nurse today"}], 'skill_id': 1.2, 'status': True}, {'conv_part': 'Initiating the session', 'description': 'Demonstrates respect and interest; attends to patient’s physical comfort', 'name': '', 'skill_id': 1.3, 'status': False}, {'conv_part': 'Initiating the session', 'description': 'Confirms issues to be discussed/screens for further questions and negotiates the agenda', 'name': '', 'skill_id': 1.5, 'status': False}]}, {'description': 'Clarifies the patient’s prior knowledge and desire for information', 'item_id': 2, 'name': 'item_problem_clarification', 'rating': 1, 'skill_sets': [{'conv_part': 'Initiating the session', 'description': 'Listens attentively, allowing the patient to complete statements without interruption and leaving space for patient', 'name': '', 'skill_id': 2.1, 'status': True}, {'conv_part': 'Gathering information', 'description': 'Encourages the patient to tell the story of the problem(s) from when it/they first started to the present in his/her own words', 'name': '', 'skill_id': 2.2, 'status': False}, {'conv_part': 'Gathering information', 'description': 'Uses open and closed questioning techniques, appropriately moving from open to closed questions', 'keywords': [{'closed_questions': [], 'open questions': []}], 'name': '', 'skill_id': 2.3, 'status': False}, {'conv_part': 'Gathering information', 'description': 'Clarifies patient’s statements that are unclear or need amplification', 'name': '', 'skill_id': 2.4, 'status': False}]}, {'description': 'Uses easily understood language, avoids jargon', 'item_id': 3, 'name': 'item_language_clarity', 'rating': 0, 'skill_sets': [{'conv_part': 'Building relationship', 'description': 'Uses easily understood language, avoids jargon', 'name': '', 'skill_id': 3.1, 'status': True}]}, {'description': 'Uses appropriate non-verbal behaviour', 'item_id': 4, 'name': 'item_non_verbal_behaviour', 'rating': 2, 'skill_sets': [{'conv_part': 'Building relationship', 'description': 'Calm speaking paces', 'keywords': [{'average speaking rate': 230, 'average syllables rate': 230}], 'name': '', 'skill_id': 4.1, 'status': False}, {'conv_part': 'Building relationship', 'description': 'Leaves space for the patient to talk', 'keywords': [{'Ratio of Patient to Doctor Speech Time': '0.5 s'}], 'name': '', 'skill_id': 4.3, 'status': True}, {'conv_part': 'Building relationship', 'description': 'Pausing', 'keywords': [{'average pause between words': '0.2 s'}], 'name': '', 'skill_id': 4.4, 'status': True}]}, {'description': 'Provide support: expresses concern and willingness to help', 'item_id': 5, 'name': 'item_patient_support', 'rating': 4, 'skill_sets': [{'conv_part': 'Building relationship', 'description': 'Accepts the legitimacy of the patient’s views and feelings; is not judgmental', 'keywords': [[{'end_time': 23.44, 'start_time': 20.09, 'text': 'got a little overzealous there, staying nice to meet you'}], [{'end_time': 25.56, 'start_time': 24.41, 'text': "i'm gonna be your nurse today"}], [{'end_time': 26.62, 'start_time': 25.57, 'text': 'i may be taking a look at you'}], [{'end_time': 32.54, 'start_time': 30.7, 'text': 'your face is nice and symmetrical here'}], [{'end_time': 33.94, 'start_time': 32.67, 'text': 'go ahead and smile for me'}], [{'end_time': 38.08, 'start_time': 36.69, 'text': 'flip your eyebrows for me'}], [{'end_time': 41.02, 'start_time': 38.67, 'text': 'close your eyes nice and tight and let me open'}], [{'end_time': 44.23, 'start_time': 42.74, 'text': 'pop your cheeks out for me'}], [{'end_time': 47.77, 'start_time': 46.1, 'text': "i'm gonna take a look in your eyes here"}], [{'end_time': 49.84, 'start_time': 48.79, 'text': 'look up at the ceiling'}], [{'end_time': 52.27, 'start_time': 50.84, 'text': 'you guys look good here'}], [{'end_time': 54.28, 'start_time': 53.06, 'text': 'let me grab my time, right'}], [{'end_time': 79.08, 'start_time': 77.06, 'text': 'follow my finger with your eyes'}], [{'end_time': 89.02, 'start_time': 84.07, 'text': 'look right at the top of the door, right there, ok, and refocus on my finger'}], [{'end_time': 105.36, 'start_time': 103.95, 'text': "we're gonna move on to your novels too"}], [{'end_time': 111.68, 'start_time': 110.35, 'text': 'go ahead and plug one side'}]], 'name': '', 'relevant_timeframes': [{'end_time': 23.44, 'start_time': 20.09, 'text': 'got a little overzealous there, staying nice to meet you'}, {'end_time': 25.56, 'start_time': 24.41, 'text': "i'm gonna be your nurse today"}, {'end_time': 26.62, 'start_time': 25.57, 'text': 'i may be taking a look at you'}, {'end_time': 32.54, 'start_time': 30.7, 'text': 'your face is nice and symmetrical here'}, {'end_time': 33.94, 'start_time': 32.67, 'text': 'go ahead and smile for me'}, {'end_time': 38.08, 'start_time': 36.69, 'text': 'flip your eyebrows for me'}, {'end_time': 41.02, 'start_time': 38.67, 'text': 'close your eyes nice and tight and let me open'}, {'end_time': 44.23, 'start_time': 42.74, 'text': 'pop your cheeks out for me'}, {'end_time': 47.77, 'start_time': 46.1, 'text': "i'm gonna take a look in your eyes here"}, {'end_time': 49.84, 'start_time': 48.79, 'text': 'look up at the ceiling'}, {'end_time': 52.27, 'start_time': 50.84, 'text': 'you guys look good here'}, {'end_time': 54.28, 'start_time': 53.06, 'text': 'let me grab my time, right'}, {'end_time': 79.08, 'start_time': 77.06, 'text': 'follow my finger with your eyes'}, {'end_time': 89.02, 'start_time': 84.07, 'text': 'look right at the top of the door, right there, ok, and refocus on my finger'}, {'end_time': 105.36, 'start_time': 103.95, 'text': "we're gonna move on to your novels too"}, {'end_time': 111.68, 'start_time': 110.35, 'text': 'go ahead and plug one side'}], 'skill_id': 5.1, 'status': True}, {'conv_part': 'Building relationship', 'description': 'Uses empathy to communicate understanding and appreciation of the patient’s feelings', 'keywords': [[{'end_time': 26.62, 'start_time': 25.57, 'text': 'i may be taking a look at you'}], [{'end_time': 33.94, 'start_time': 32.67, 'text': 'go ahead and smile for me'}], [{'end_time': 41.02, 'start_time': 38.67, 'text': 'close your eyes nice and tight and let me open'}], [{'end_time': 47.77, 'start_time': 46.1, 'text': "i'm gonna take a look in your eyes here"}], [{'end_time': 52.27, 'start_time': 50.84, 'text': 'you guys look good here'}], [{'end_time': 105.36, 'start_time': 103.95, 'text': "we're gonna move on to your novels too"}], [{'end_time': 111.68, 'start_time': 110.35, 'text': 'go ahead and plug one side'}]], 'name': '', 'relevant_timeframes': [{'end_time': 26.62, 'start_time': 25.57, 'text': 'i may be taking a look at you'}, {'end_time': 33.94, 'start_time': 32.67, 'text': 'go ahead and smile for me'}, {'end_time': 41.02, 'start_time': 38.67, 'text': 'close your eyes nice and tight and let me open'}, {'end_time': 47.77, 'start_time': 46.1, 'text': "i'm gonna take a look in your eyes here"}, {'end_time': 52.27, 'start_time': 50.84, 'text': 'you guys look good here'}, {'end_time': 105.36, 'start_time': 103.95, 'text': "we're gonna move on to your novels too"}, {'end_time': 111.68, 'start_time': 110.35, 'text': 'go ahead and plug one side'}], 'skill_id': 5.2, 'status': True}, {'conv_part': 'Building relationship', 'description': 'Provides support: expresses concern, understanding, and willingness to help', 'keywords': [[{'end_time': 23.44, 'start_time': 20.09, 'text': 'got a little overzealous there, staying nice to meet you'}], [{'end_time': 25.56, 'start_time': 24.41, 'text': "i'm gonna be your nurse today"}], [{'end_time': 38.08, 'start_time': 36.69, 'text': 'flip your eyebrows for me'}], [{'end_time': 44.23, 'start_time': 42.74, 'text': 'pop your cheeks out for me'}], [{'end_time': 54.28, 'start_time': 53.06, 'text': 'let me grab my time, right'}]], 'name': '', 'relevant_timeframes': [{'end_time': 23.44, 'start_time': 20.09, 'text': 'got a little overzealous there, staying nice to meet you'}, {'end_time': 25.56, 'start_time': 24.41, 'text': "i'm gonna be your nurse today"}, {'end_time': 38.08, 'start_time': 36.69, 'text': 'flip your eyebrows for me'}, {'end_time': 44.23, 'start_time': 42.74, 'text': 'pop your cheeks out for me'}, {'end_time': 54.28, 'start_time': 53.06, 'text': 'let me grab my time, right'}], 'skill_id': 5.3, 'status': True}]}, {'description': 'Structures the interview in a logical sequence', 'item_id': 6, 'name': 'item_interview_structure', 'rating': 4, 'skill_sets': [{'conv_part': 'Providing Structure', 'description': 'Progresses from one section to another using Signposting', 'keywords': ['here'], 'name': '', 'relevant_timeframes': [{'end_time': 11.34, 'start_time': 11.04, 'text': 'here'}, {'end_time': 32.54, 'start_time': 32.25, 'text': 'here'}, {'end_time': 47.77, 'start_time': 47.4, 'text': 'here'}, {'end_time': 52.27, 'start_time': 51.82, 'text': 'here'}, {'end_time': 75.97, 'start_time': 75.47, 'text': 'here'}, {'end_time': 93.77, 'start_time': 93.4, 'text': 'here'}], 'skill_id': 6.1, 'status': True}, {'conv_part': 'Providing Structure', 'description': 'Progresses from one section to another using Transitional statements', 'keywords': ['to', 'up', 'here', 'and', 'there', 'for'], 'name': '', 'relevant_timeframes': [{'end_time': 5.99, 'start_time': 5.52, 'text': 'and'}, {'end_time': 6.73, 'start_time': 6.66, 'text': 'to'}, {'end_time': 8.27, 'start_time': 8.16, 'text': 'to'}, {'end_time': 10.08, 'start_time': 9.86, 'text': 'and'}, {'end_time': 11.34, 'start_time': 11.04, 'text': 'here'}, {'end_time': 11.77, 'start_time': 11.54, 'text': 'and'}, {'end_time': 18.22, 'start_time': 17.89, 'text': 'and'}, {'end_time': 21.46, 'start_time': 21.19, 'text': 'there'}, {'end_time': 23.08, 'start_time': 22.97, 'text': 'to'}, {'end_time': 28.71, 'start_time': 28.65, 'text': 'to'}, {'end_time': 31.58, 'start_time': 31.49, 'text': 'and'}, {'end_time': 32.54, 'start_time': 32.25, 'text': 'here'}, {'end_time': 33.15, 'start_time': 33.05, 'text': 'and'}, {'end_time': 33.67, 'start_time': 33.51, 'text': 'for'}, {'end_time': 37.88, 'start_time': 37.68, 'text': 'for'}, {'end_time': 39.61, 'start_time': 39.47, 'text': 'and'}, {'end_time': 40.39, 'start_time': 40.23, 'text': 'and'}, {'end_time': 43.97, 'start_time': 43.72, 'text': 'for'}, {'end_time': 47.77, 'start_time': 47.4, 'text': 'here'}, {'end_time': 49.17, 'start_time': 49.03, 'text': 'up'}, {'end_time': 52.27, 'start_time': 51.82, 'text': 'here'}, {'end_time': 57.16, 'start_time': 57.06, 'text': 'up'}, {'end_time': 75.97, 'start_time': 75.47, 'text': 'here'}, {'end_time': 79.47, 'start_time': 79.39, 'text': 'to'}, {'end_time': 80.47, 'start_time': 80.4, 'text': 'and'}, {'end_time': 86.18, 'start_time': 85.83, 'text': 'there'}, {'end_time': 87.64, 'start_time': 87.53, 'text': 'and'}, {'end_time': 91.97, 'start_time': 91.78, 'text': 'to'}, {'end_time': 93.77, 'start_time': 93.4, 'text': 'here'}, {'end_time': 104.66, 'start_time': 104.57, 'text': 'to'}, {'end_time': 110.84, 'start_time': 110.72, 'text': 'and'}], 'skill_id': 6.2, 'status': True}, {'conv_part': 'Providing Structure', 'description': 'Progresses from one section to another using Rationale for the next section', 'name': '', 'skill_id': 6.3, 'status': True}]}, {'description': 'Attends to timekeeping, and keeps the interview on track', 'item_id': 7, 'name': 'item_timekeeping', 'rating': 1, 'skill_sets': [{'description': 'Structures the interview based on the C-CG', 'name': '', 'skill_id': 7.1, 'status': True}, {'conv_part': 'Providing Structure', 'description': 'Attending to timing', 'keywords': [{'interview time': '111.81'}], 'name': '', 'skill_id': 7.2, 'status': False}]}, {'description': 'Shares thoughts and reflections with the patient', 'item_id': 8, 'name': 'item_thought _sharing', 'rating': 1, 'skill_sets': [{'conv_part': 'Explanation and planning', 'description': 'Assesses patient’s starting point (preferably using tailored explanations and illustrations)', 'name': '', 'skill_id': 8.1, 'status': False}, {'conv_part': 'Explanation and planning', 'description': 'Provides information in manageable chunks, assesses understanding uses patient’s responses as a guide for the best way to proceed', 'keywords': {'doctor_lengthy_dialogues': ["look right at the top of the door, right there, ok, and refocus on my finger.i'm going to feel your tear glands here in your lab.we're gonna move on to your novels too"], 'relevant_connected_doctor_patient_conversation': []}, 'name': '', 'skill_id': 8.2, 'status': False}]}, {'description': 'Checks the patient’s understanding', 'item_id': 9, 'name': 'item_check_understanding', 'rating': 0, 'skill_sets': [{'conv_part': 'Explanation and planning', 'description': 'Organizes the explanation (uses summarizing)', 'name': '', 'skill_id': 9.1, 'status': False}, {'conv_part': 'Explanation and planning', 'description': 'Assesses the patient’s understanding (asks the patient to summarize the information he/she was provided)', 'keywords': [], 'name': '', 'skill_id': 9.2, 'status': False}]}, {'description': 'Negotiates a mutual plan of action', 'item_id': 10, 'name': 'item_patient_plan', 'rating': 1, 'skill_sets': [{'conv_part': 'Explanation and planning', 'description': 'Explores options with the patient', 'name': '', 'skill_id': 10.1, 'status': False}, {'conv_part': 'Explanation and planning', 'description': 'Involves the patient in decision making', 'name': '', 'skill_id': 10.2, 'status': False}, {'description': 'Negotiates a mutually acceptable plan', 'name': '', 'skill_id': 10.3, 'status': False}]}, {'description': 'Contracts with the patient about next steps', 'item_id': 11, 'name': 'item_patient_contract', 'rating': 1, 'skill_sets': [{'conv_part': 'Closing the session', 'description': ' Safety nets, e.g., phone number and other lifelines', 'name': '', 'skill_id': 11.2, 'status': False}]}, {'description': 'Summarizes the session briefly and clarifies the plan of care', 'item_id': 12, 'name': 'item_session_summary', 'rating': 1, 'skill_sets': [{'conv_part': 'Closing the session', 'description': 'Final confirmation of patient understanding', 'name': '', 'skill_id': 12.1, 'status': False}, {'conv_part': 'Closing the session', 'description': 'Finally confirms that the patient agrees and is comfortable with the plan', 'name': '', 'skill_id': 12.3, 'status': False}]}], 'filename': 'DCW3VXB0PFZUHD6ZMJAC7VH3J61093FS.mp4', 'message': 'Successfully retrieved assessment details.', 'success': True}
